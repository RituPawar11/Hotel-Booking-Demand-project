# %% [markdown]
# **Hotel Booking Demand**

# %% [markdown]
# Importing all the necessary libraries
#
# *   Pandas is a Python library used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# *   NumPy is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.
#
# *   Matplotlib is a cross-platform, data visualization and graphical plotting library (histograms, scatter plots, bar charts, etc) for Python and its numerical extension NumPy.
#
# *   Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# We use pandas.read_csv() function to read the csv file.
#
# In brackets, we put the file path along with a quotation mark, so that pandas will read the file into a data frame from that address. The file path can be either an URL or your local file address.
#
# Name of Dataset is "hotel_bookings.csv"

# %%
#Read the dataset in "df" variable
df=pd.read_csv("hotel_bookings.csv")

# %% [markdown]
# After reading the dataset, we can use the dataframe.head(n) method to check the top n rows of the dataframe; where n is an integer. Contrary to dataframe.head(n), dataframe.tail(n) will show you the bottom n rows of the dataframe.

# %%
# show the first 5 rows using dataframe.head() method
print("The first 5 rows of the dataframe")
df.head(5)
# Out:
# The first 5 rows of the dataframe
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# ...

# %%
#show the last 10 rows of the dataframe.
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.

# %%
#to display all the columns of the data set
pd.set_option('display.max_columns',32)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
#to display all the column names
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# :From above we can see that the data set contains 32 columns and 119390 rows. All the columns are:
#
# *   Hotel: H1 = Resort Hotel or H2 = City Hotel
# *   is_canceled: Value indicating if the booking was canceled (1) or not (0)
# *   lead_time: Number of days that elapsed between the entering date of the booking into the PMS and the arrival date.
# *   arrival_date_year: Year of arrival date.
# *   arrival_date_month: Month of arrival date.
# *   arrival_date_week_number: Week number of year for arrival date.
# *   arrival_date_day_of_month: Day of arrival date.
# *   stays_in_weekend_nights: Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
# *   stays_in_week_nights: Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
# *   adults: Number of adults
# *   children: Number of children
# *   babies: Number of babies
# *   meal: Type of meal booked. Categories are presented in standard hospitality meal packages. Categories are Undefined/SC, BB, HB, Other
# *   country: Country of origin.
# *   market_segment: Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# *   distribution_channel: Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”
# *   is_repeated_guest: Value indicating if the booking name was from a repeated guest (1) or not (0)
# *   previous_cancellations: Number of previous bookings that were cancelled by the customer prior to the current booking
# *   previous_bookings_not_canceled: Number of previous bookings not cancelled by the customer prior to the current booking
# *   reserved_room_type: Code of room type reserved. Code is presented instead of designation for anonymity reasons.
# *   assigned_room_type: Code for the type of room assigned to the booking.
# *   booking_changes: Number of changes/amendments made to the booking from the moment the booking
# *   deposit_type: Indication on if the customer made a deposit to guarantee the booking.
# *   agent: ID of the travel agency that made the booking
# *   company: ID of the company/entity that made the booking or responsible for paying the booking.
# *   days_in_waiting_list: Number of days the booking was in the waiting list before it was confirmed to the customer.
# *   customer_type: Type of booking, assuming one of four categories: Contract, Transient, Transient-Party, Other
# *   adr: Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights.
# *   required_car_parking_spaces: Number of car parking spaces required by the customer
# *   total_of_special_requests: Number of special requests made by the customer (e.g. twin bed or high floor)
# *   reservation_status: Reservation last status, assuming one of three categories: Canceled, Check-Out, Other
# *   reservation_status_date: Date at which the last status was set.

# %% [markdown]
# **Basic Insight of Dataset:**
#
# After reading data into Pandas dataframe, it is time for us to explore the dataset. There are several ways to obtain essential insights of the data to help us better understand our dataset.

# %% [markdown]
# **Data Type**
#
# Data has a variety of types. The main types stored in Pandas dataframes are object, float, int, bool and datetime64.
#
# In Pandas:
#
# Syntax : dataframe.dtypes
#
# returns a Series with the data type of each column.

# %%
# check the data type of data frame "df" by .dtypes
print(df.dtypes)
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# **Sample**

# %%
#gives random 10 data
df.sample(10)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30310   Resort Hotel            0         33               2016
# 74826     City Hotel            1        335               2015
# 88795     City Hotel            0         88               2016
# 12407   Resort Hotel            1        309               2017
# 114936    City Hotel            0         34               2017
# 108628    City Hotel            0          0               2017
# 64465     City Hotel            1         98               2017
# 54518     City Hotel            1        116               2016
# 35004   Resort Hotel            0         20               2017
# 44137     City Hotel            0         85               2015
#
#        arrival_date_month  arrival_date_week_number  \
# 30310            November                        47
# 74826           September                        38
# 88795                 May                        20
# ...

# %% [markdown]
# **Describe**
#
# If we would like to get a statistical summary of each column, such as count, column mean value, column standard deviation, etc. We use the describe method.

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# **Info**
#
# This method prints information about a DataFrame including the index dtype and columns, non-null values and memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#to get unique values for all columns
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
#to find diffrent categories of hotel
df['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %% [markdown]
# From above we can see the total number of resort hotel and city hotel guests.
# We can see that city hotel has more number of records than resort hotel. So, we can say that it is not a balanced data set.

# %%
#to find different categories of meal
df['meal'].value_counts()
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %%
#to find different categories of market_segment
df['market_segment'].value_counts()
# Out:
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: market_segment, dtype: int64

# %%
#to find different categories of distribution_channel
df['distribution_channel'].value_counts()
# Out:
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
#to find different categories of deposit_type
df['deposit_type'].value_counts()
# Out:
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: deposit_type, dtype: int64

# %%
#to find different categories of customer_type
df['customer_type'].value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %%
#to find different categories of special requests
df['total_of_special_requests'].value_counts()
# Out:
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: total_of_special_requests, dtype: int64

# %% [markdown]
# **Duplicate Values**

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# There are 31994 duplicate values in the dataset

# %%
#Dropping the duplicate values
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# We have deleted the dupicated data. Now, we have 87396 rows.

# %% [markdown]
# **Evaluating for Missing Data**
#
# The missing values are converted to default. We use the following functions to identify these missing values. There are two methods to detect missing data:
#
#
# 1.   isnull()
#
# 2.   notnull()

# %%
#to check if the null value is present or not in the dataframe
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# True shows that the null values are present in the data set

# %%
#to check the columns that have null values
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [markdown]
# From above we can see that children column has 4 null values, country coulmn has 452 null values, agent column has 12193 null values and company column has 82137 null values. Maximum null values are present in company column.

# %%
# Visualizing the missing values using Seaborn heatmap
plt.figure(figsize=(20,8))
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.title('Missing Values', fontsize=18)
plt.show()

# %% [markdown]
# **Deal with missing data**
#
# drop data
#
# a. drop the whole row
#
# b. drop the whole column
#
# replace data
#
# a. replace it by mean
#
# b. replace it by frequency
#
# Whole columns should be dropped only if most entries in the column are empty.

# %%
#as most of the data in company and agent column is empty we will drop them
df=df.drop(['agent',
            'company'],axis=1)
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.shape
# Out:
# (87396, 30)

# %% [markdown]
# Now, we have 30 columns.

# %%
#replacing null values with 0
df.fillna(0,inplace=True)
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# Here, we have replaced all the null values with 0. So, we do not have any null value in our data set.

# %%
#meal contains value undefined which can be replaced by SC
df['meal'].replace("Undefined","SC",inplace=True)

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC'], dtype=object)

# %% [markdown]
# We can see that the undefined is not present in the meal column now

# %% [markdown]
# **Deleting unnecessary data**

# %%
#If number of guest is 0 then the data is invalid
subset=df[(df['children']==0) & (df['adults']==0) & (df['babies']==0)]

# %%
subset[['adults','babies','children']]
# Out:
#         adults  babies  children
# 2224         0       0       0.0
# 2409         0       0       0.0
# 3181         0       0       0.0
# 3684         0       0       0.0
# 3708         0       0       0.0
# ...        ...     ...       ...
# 115029       0       0       0.0
# 115091       0       0       0.0
# 116251       0       0       0.0
# 116534       0       0       0.0
# 117087       0       0       0.0
#
# [166 rows x 3 columns]

# %% [markdown]
# From above we can see that 166 entries are invalid. Therefore we will delete them.

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
delete=(df['children']==0) & (df['adults']==0) & (df['babies']==0)

# %%
type(delete)
# Out:
# pandas.core.series.Series

# %%
delete
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Length: 87396, dtype: bool

# %%
data=df[~delete]

# %%
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
data.shape
# Out:
# (87230, 30)

# %% [markdown]
# 166 rows are deleted from the dataset that were invalid.

# %% [markdown]
# We have corrected dataset and stored it in data.

# %%
subset=data[(data['children']==0) & (data['adults']==0) & (data['babies']==0)]

# %%
subset
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []

# %% [markdown]
# From above we can see that all the invalid rows are removed.

# %% [markdown]
# After manipulating the dataset these are the insights:
#
# 1. There are 2 types of hotel which guests could book.
#
# 2. There are different types of guests and they come from different countries.
#
# 3. Guests can choose different foods from the menu.
#
# 4. Guests can book hotel directly or through different channels that are available.
#
# 5. Guests can cancel their booking and there are repeated guests also.
#
# 6. Guests can choose rooms of their liking while booking.
#
# 7. There is column available in the dataset named 'adr' which could be used to analyze hotel's performance on the basis of revenue.

# %% [markdown]
# **Data Visualization**

# %%
sns.countplot(data=data,x="hotel")
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %% [markdown]
# From above we can see that city hotel has more number of records than resort hotel

# %%
#Bar plot: Booking Status
sns.countplot(x='is_canceled', data=data)
plt.title('Booking Status')
plt.show()

# %%
#Histogram: Lead Time
plt.hist(data['lead_time'], bins=30)
plt.xlabel('Lead Time (days)')
plt.ylabel('Count')
plt.title('Distribution of Lead Time')
plt.show()

# %% [markdown]
# Above graph shows the distribution of the lead time

# %%
sns.countplot(data=data,x="hotel",hue="is_canceled")
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %% [markdown]
# Here, we can see that number of cancellations is more in city hotel as compaired to Resort hotel.

# %%
#Box plot: Booking Lead Time vs. Hotel Type
sns.boxplot(x='hotel', y='lead_time', data=data)
plt.xlabel('Hotel Type')
plt.ylabel('Lead Time (days)')
plt.title('Booking Lead Time vs. Hotel Type')
plt.show()

# %% [markdown]
# **Which type of hotel is most preferred by the guests?**

# %%
# Count Hotel
hotel_count = data.hotel.value_counts()

# Plotting Values in a simple pie chart
hotel_count.plot.pie(figsize=(9,7), autopct='%1.2f%%', shadow=True, fontsize=15,startangle=50)

# Setting the title
plt.title('Hotel Booking Percentage')
plt.axis('equal')
plt.show()

# %% [markdown]
# We can see that guests prefer Resort Hotel most over City Hotel. As the percentage of city hotel i.e 61.07 is more than that of resort hotel i.e 38.93

# %% [markdown]
# **What is perecentage of hotel booking cancellation?**

# %%
# Extracting and storing unique values of hotel cancelation
cancelled_hotel = data.is_canceled.value_counts()

# Craeting a pie chart
cancelled_hotel.plot.pie(figsize=(9,7),explode=(0.05,0.05),autopct='%1.2f%%',shadow=True,fontsize=12,startangle=50)

# Giving our pie chart a title
plt.title('Percentage of Hotel Cancellation and Non Cancellation')
plt.axis('equal')
plt.show()

# %% [markdown]
# Here, we can see that around 72.48% bookings are not canceled by guests but around 27.52% bookings are canceled by guests.

# %% [markdown]
# **Which type of meal is most preffered by guests?**

# %%
# Counting each meal type and storing it in a new DataFrame meal_df
meal_df = data['meal'].value_counts().reset_index()
meal_df.columns = ['meal name', 'meal count']

# Visualizing the values on a bar chart
plt.figure(figsize=(15, 5))
sns.barplot(data=meal_df, x='meal name', y='meal count')
plt.title('Most Preferred Meal Type', fontsize=25)
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotates the x-axis labels for better visibility
plt.show()

# %% [markdown]
# Meal type variable description:
#
# BB - Bed and Breakfast
#
# HB- Half Board
#
# FB- Full Board
#
# SC- Self Catering

# %% [markdown]
# After visualizing the above chart we can see that BB - (Bed and Breakfast) is the most preffered meal type by guests.

# %% [markdown]
# **Which year has the most bookings ?**

# %%
# Plotting with countplot
plt.figure(figsize=(10,4))
sns.countplot(x=data['arrival_date_year'],hue=data['hotel'])
plt.title("Number of bookings across year", fontsize = 25)
plt.show()

# %% [markdown]
# We can see that there were maximum bookings in the year 2016

# %% [markdown]
# **Which month has the most bookings in each hotel type?**

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=data['arrival_date_month'],hue=data['hotel'])
plt.title("Number of booking across months", fontsize = 25)
plt.show()

# %% [markdown]
# From above we can see that there were maximum numbers of bookings in August month

# %% [markdown]
# **Most guests came from which country?**

# %%
# Coounting number of guests from various countries and changing column names
country_df = data['country'].value_counts().head(10).reset_index()
country_df.columns = ['country', 'guests count']

# Visualizing the values on a bar chart
plt.figure(figsize=(15, 4))
sns.barplot(x='country', y='guests count', data=country_df)
plt.title('Number of Guests from Each Country', fontsize=20)
plt.xlabel('Country')
plt.ylabel('Number of Guests')
plt.xticks(rotation=45)  # Rotates the x-axis labels for better visibility
plt.show()

# %% [markdown]
# From above we can see that most guests come from PRT(Portugal).

# %% [markdown]
# **Which room type is most preferred by guests?**

# %%
# Setting the figure size
plt.figure(figsize=(15,5))

# Plotting the values in chart
sns.countplot(x=data['reserved_room_type'],order=data['reserved_room_type'].value_counts().index)

# Setting the title
plt.title('Preferred Room Type by Guests', fontsize = 25)

# Show the chart
plt.show()

# %% [markdown]
# We can see that the most preferred room type is A i.e almost 55000 guests.

# %% [markdown]
# **What is the percentage of repeated guests?**

# %%
# Creating a variable containing guests with their repeated counts
rep_guests = data['is_repeated_guest'].value_counts()

# Plotting the values in a pie chart
rep_guests.plot.pie(autopct='%1.2f%%', explode=(0.01,0.09), figsize=(15,6), shadow=False)

# Setting the title
plt.title('Percentage of Repeated Guests', fontsize=20)

# Setting the chart in centre
plt.axis('equal')

# Show the chart
plt.show()

# %% [markdown]
# From above we can see that 3.86% guests are repeated guests.

# %% [markdown]
# **Which Market Segment has the most booking?**

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=data['market_segment'], order = data['market_segment'].value_counts().index)
plt.title('Market segment sahre in booking', fontsize=20)
plt.show()

# %% [markdown]
# From above we can see that the online segment has the most bookings.

# %%
# Correlation Heatmap visualization
# Setting the chart size
plt.figure(figsize=(15,10))

# Creating heatmap to see correlation of each columns
sns.heatmap(data.corr(numeric_only=True),annot=True)          # Setting the numeric only colun to True to avoid warning

# Setting the title
plt.title('Correlation of the columns', fontsize=20)

# Show heatmap
plt.show()

# %% [markdown]
# 1) lead_time and total_stay is positively corelated, that means if customers stay more then the lead time increases.
#
# 2) adults, childrens and babies are corelated to each other, that means more the people more will be adr.
#
# 3) is_repeated guest and previous bookings not canceled has strong corelation, that means repeated guests don't cancel their bookings.

# %% [markdown]
# **Skewness**

# %% [markdown]
# Skewness is a statistical measure that quantifies the asymmetry in the probability distribution of a dataset. It indicates the extent to which the data is skewed or deviates from a symmetrical distribution. A symmetrical distribution has equal probabilities for values on either side of the central tendency, such as the mean, median, and mode.
#
# It is commonly used to identify the presence of outliers or unusual patterns in the data.
#
# There are two types of skewness:
# 1. Positive skewness
# 2. Negative skewness
#
# Skewness can be calculated for any numerical column in a dataset.

# %%
# Calculate the skewness of the 'lead_time'
lead_time_skewness = data['lead_time'].skew()

print("Skewness of 'lead_time':", lead_time_skewness)
# Out:
# Skewness of 'lead_time': 1.4307521377858154

# %% [markdown]
#  A skewness value of 'lead_time' is 1.4307521377858154. Which indicates that the 'lead_time' feature in the "Hotel Booking Demand" dataset is positively skewed or right-skewed.

# %% [markdown]
# Calculating the Skewness of all the numerical columns

# %%
df.skew()
# Out:
# <ipython-input-67-9e0b1e29546f>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.skew()
# is_canceled                        1.008396
# lead_time                          1.431774
# arrival_date_year                 -0.297194
# arrival_date_week_number           0.022504
# arrival_date_day_of_month          0.000308
# stays_in_weekend_nights            1.411637
# stays_in_week_nights               2.691321
# adults                            19.859578
# children                           3.463670
# babies                            21.148519
# is_repeated_guest                  4.757441
# previous_cancellations            34.323744
# previous_bookings_not_canceled    20.459725
# booking_changes                    5.546328
# ...

# %% [markdown]
# From above we can see that only arrival_date_year is negatively skewed. While the other columns are positively skewed.
#
# We can see that some of the columns such as previous_cancellations, babies, adults, previous_bookings_not_canceled, adr have high positive value. Inidicating that they are highly skewed towards right.

# %% [markdown]
# **Detecting Outliers**

# %%
# Visual inspection using box plots
sns.boxplot(x=data['lead_time'])
# Out:
# <Axes: xlabel='lead_time'>

# %%
#detecting outlier for arrival_date_year column
sns.boxplot(x=data['arrival_date_year'])
# Out:
# <Axes: xlabel='arrival_date_year'>

# %%
#detecting outlier for adults column
sns.boxplot(x=data['adults'])
# Out:
# <Axes: xlabel='adults'>

# %%
#detecting outlier for booking_changes column
sns.boxplot(x=data['booking_changes'])
# Out:
# <Axes: xlabel='booking_changes'>

# %%
#detecting outlier for total_of_special_requests column
sns.boxplot(x=data['total_of_special_requests'])
# Out:
# <Axes: xlabel='total_of_special_requests'>

# %% [markdown]
# **Removing Outliers**

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# is_canceled                         1.00
# lead_time                         114.00
# arrival_date_year                   1.00
# arrival_date_week_number           21.00
# arrival_date_day_of_month          15.00
# stays_in_weekend_nights             2.00
# stays_in_week_nights                3.00
# adults                              0.00
# children                            0.00
# babies                              0.00
# is_repeated_guest                   0.00
# previous_cancellations              0.00
# previous_bookings_not_canceled      0.00
# booking_changes                     0.00
# days_in_waiting_list                0.00
# adr                                61.85
# required_car_parking_spaces         0.00
# total_of_special_requests           1.00
# dtype: float64
# ...

# %%
data= data[~((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR))).any(axis=1)]
data.shape
# Out:
# <ipython-input-74-6ff698f5666d>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   data= data[~((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR))).any(axis=1)]
# (39733, 30)

# %%
sns.boxplot(x=data['lead_time'])
# Out:
# <Axes: xlabel='lead_time'>

# %%
sns.boxplot(x=data['arrival_date_year'])
# Out:
# <Axes: xlabel='arrival_date_year'>

# %%
sns.boxplot(x=data['adults'])
# Out:
# <Axes: xlabel='adults'>

# %%
sns.boxplot(x=data['booking_changes'])
# Out:
# <Axes: xlabel='booking_changes'>

# %% [markdown]
# No outliers are present in the data now.

# %% [markdown]
# **Dropping unwanted columns**

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data=data.drop(['stays_in_weekend_nights','stays_in_week_nights', 'adults', 'children', 'babies', 'meal','country', 'market_segment', 'distribution_channel', 'reserved_room_type',
       'assigned_room_type', 'deposit_type','customer_type',
        'reservation_status', 'reservation_status_date'], axis=1)

# %%
data=data.drop(['arrival_date_year','arrival_date_month'], axis=1)

# %% [markdown]
# We are deleting these columns these columns does not contain information that can be relevant in predicting whether a booking will be canceled or not.

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'days_in_waiting_list', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests'],
#       dtype='object')

# %%
data.shape
# Out:
# (39733, 13)

# %% [markdown]
# **Encoding**

# %% [markdown]
# Encoding is the process of converting data from one representation or format to another. In the context of data preprocessing and machine learning, encoding typically refers to the transformation of categorical variables into numerical form, as many machine learning algorithms work with numerical data.

# %%
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# Here, we are importing OrdinalEncoder from sklearn.preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39733 entries, 4 to 119389
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           39733 non-null  object
#  1   is_canceled                     39733 non-null  int64
#  2   lead_time                       39733 non-null  int64
#  3   arrival_date_week_number        39733 non-null  int64
#  4   arrival_date_day_of_month       39733 non-null  int64
#  5   is_repeated_guest               39733 non-null  int64
#  6   previous_cancellations          39733 non-null  int64
#  7   previous_bookings_not_canceled  39733 non-null  int64
#  8   booking_changes                 39733 non-null  int64
#  9   days_in_waiting_list            39733 non-null  int64
#  10  adr                             39733 non-null  float64
#  11  required_car_parking_spaces     39733 non-null  int64
# ...

# %% [markdown]
# Here, we can see that one columns(hotel) has object as a data type.

# %%
oe=OrdinalEncoder()
data[["hotel"]]=oe.fit_transform(data[["hotel"]])
#fit: to perform calculation on data
#transform: apply that calculation

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39733 entries, 4 to 119389
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           39733 non-null  float64
#  1   is_canceled                     39733 non-null  int64
#  2   lead_time                       39733 non-null  int64
#  3   arrival_date_week_number        39733 non-null  int64
#  4   arrival_date_day_of_month       39733 non-null  int64
#  5   is_repeated_guest               39733 non-null  int64
#  6   previous_cancellations          39733 non-null  int64
#  7   previous_bookings_not_canceled  39733 non-null  int64
#  8   booking_changes                 39733 non-null  int64
#  9   days_in_waiting_list            39733 non-null  int64
#  10  adr                             39733 non-null  float64
#  11  required_car_parking_spaces     39733 non-null  int64
# ...

# %% [markdown]
# Now, we can see that none of the columns has object as data type.

# %%
data.head()
# Out:
#    hotel  is_canceled  lead_time  arrival_date_week_number  \
# 4    1.0            0         14                        27
# 6    1.0            0          0                        27
# 7    1.0            0          9                        27
# 8    1.0            1         85                        27
# 9    1.0            1         75                        27
#
#    arrival_date_day_of_month  is_repeated_guest  previous_cancellations  \
# 4                          1                  0                       0
# 6                          1                  0                       0
# 7                          1                  0                       0
# 8                          1                  0                       0
# 9                          1                  0                       0
#
#    previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 4                               0                0                     0
# ...

# %% [markdown]
# Here 1 stands for resort hotel and 0 for city hotel

# %% [markdown]
# **Data Preprocessing**

# %% [markdown]
# Data preprocessing is a crucial step in data analysis and machine learning workflows. It involves cleaning, transforming, and preparing raw data into a format suitable for analysis or modeling. The goal of data preprocessing is to ensure that the data is accurate, consistent, and in a suitable form that can be used effectively for further analysis or to build machine learning models.

# %%
# Assuming 'desired_column' is the column you want to bring to the first position
desired_column = 'is_canceled'

# Separate the desired column from the DataFrame
selected_column = data[desired_column]

# Drop the desired column from its original position
data.drop(columns=[desired_column], inplace=True)

# Concatenate the selected column to the DataFrame at the beginning
data = pd.concat([selected_column, data], axis=1)

# %% [markdown]
# We are shifting "is_canceled" column to make slicing much easier

# %%
data.head()
# Out:
#    is_canceled  hotel  lead_time  arrival_date_week_number  \
# 4            0    1.0         14                        27
# 6            0    1.0          0                        27
# 7            0    1.0          9                        27
# 8            1    1.0         85                        27
# 9            1    1.0         75                        27
#
#    arrival_date_day_of_month  is_repeated_guest  previous_cancellations  \
# 4                          1                  0                       0
# 6                          1                  0                       0
# 7                          1                  0                       0
# 8                          1                  0                       0
# 9                          1                  0                       0
#
#    previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 4                               0                0                     0
# ...

# %% [markdown]
# Now, we can see that is_canceled column is shifted to the 1st position

# %% [markdown]
# Here, we can see that the index value in not in proper order. So, we are going to reset it.

# %%
data1 = data.reset_index(drop=True)

# %%
data1.head()
# Out:
#    is_canceled  hotel  lead_time  arrival_date_week_number  \
# 0            0    1.0         14                        27
# 1            0    1.0          0                        27
# 2            0    1.0          9                        27
# 3            1    1.0         85                        27
# 4            1    1.0         75                        27
#
#    arrival_date_day_of_month  is_repeated_guest  previous_cancellations  \
# 0                          1                  0                       0
# 1                          1                  0                       0
# 2                          1                  0                       0
# 3                          1                  0                       0
# 4                          1                  0                       0
#
#    previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 0                               0                0                     0
# ...

# %% [markdown]
# Now, we can see tha the DataFrame will have a new sequential integer index starting from 0.

# %%
x = data1.iloc[:,1:]
y = data1.iloc[:,0]

# %% [markdown]
# In this code, two pandas DataFrame slices are created from the DataFrame data. The slices are used to separate the features (input variables) and the target variable (output variable).

# %%
x.dtypes
# Out:
# hotel                             float64
# lead_time                           int64
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# booking_changes                     int64
# days_in_waiting_list                int64
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# dtype: object

# %%
print(x)
# Out:
#        hotel  lead_time  arrival_date_week_number  arrival_date_day_of_month  \
# 0        1.0         14                        27                          1
# 1        1.0          0                        27                          1
# 2        1.0          9                        27                          1
# 3        1.0         85                        27                          1
# 4        1.0         75                        27                          1
# ...      ...        ...                       ...                        ...
# 39728    0.0        164                        35                         31
# 39729    0.0         21                        35                         30
# 39730    0.0         23                        35                         30
# 39731    0.0        109                        35                         31
# 39732    0.0        205                        35                         29
#
# ...

# %% [markdown]
# From above we can see all the features.

# %%
print(y)
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 39728    0
# 39729    0
# 39730    0
# 39731    0
# 39732    0
# Name: is_canceled, Length: 39733, dtype: int64

# %% [markdown]
# From above we can see the target variable.

# %%
print(x.shape)
print(y.shape)
# Out:
# (39733, 12)
# (39733,)

# %% [markdown]
# **Creating Training and Testing Set**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Here, we are importing train_test_split from from sklearn.model_selection.

# %% [markdown]
# The train_test_split function is used to split a dataset into separate training and testing subsets, which are essential for training and evaluating machine learning models.

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# **Regression**

# %% [markdown]
# In our dataset, the target variable is the "is_canceled" column, which indicates whether a booking was canceled (1) or not (0). Since the target variable is binary (only two possible outcomes), it is a binary classification problem. For binary classification tasks, logistic regression is the appropriate choice, not linear regression.

# %% [markdown]
# Logistic Regression

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# Here, we are importing essential libraries for performing Logistic Regression

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
# Create and train the Logistic Regression model
model = LogisticRegression(random_state=42)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Make predictions on the test set
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# **Evaluating the model**

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 0.70

# %%
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.95      0.81      5471
#            1       0.56      0.15      0.23      2476
#
#     accuracy                           0.70      7947
#    macro avg       0.63      0.55      0.52      7947
# weighted avg       0.66      0.70      0.63      7947

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[5182  289]
#  [2113  363]]

# %%
model.score(X_train_scaled,y_train)
# Out:
# 0.6991128169634431

# %%
model.score(X_test_scaled,y_test)
# Out:
# 0.6977475777022776

# %% [markdown]
# **Making prediction on unknown data**

# %%
data1.columns
# Out:
# Index(['is_canceled', 'hotel', 'lead_time', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'booking_changes', 'days_in_waiting_list', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests'],
#       dtype='object')

# %%
data1.head()
# Out:
#    is_canceled  hotel  lead_time  arrival_date_week_number  \
# 0            0    1.0         14                        27
# 1            0    1.0          0                        27
# 2            0    1.0          9                        27
# 3            1    1.0         85                        27
# 4            1    1.0         75                        27
#
#    arrival_date_day_of_month  is_repeated_guest  previous_cancellations  \
# 0                          1                  0                       0
# 1                          1                  0                       0
# 2                          1                  0                       0
# 3                          1                  0                       0
# 4                          1                  0                       0
#
#    previous_bookings_not_canceled  booking_changes  days_in_waiting_list  \
# 0                               0                0                     0
# ...

# %%
hotel=float(input("Enter 0.0 for city hotel and 1.0 for resort hotel: "))
lead=int(input("Enter lead time: "))
week=int(input("Enter arrival date week number: "))
day=int(input("Enter arrival date day of month: "))
repeted=int(input("Enter 1 for repeted guest and 0 for not repeated guest: "))
cancellations=int(input("Enter number of previous cancallations: "))
not_canceled=int(input("Enter number of previous bookings not canceled: "))
changes=int(input("Enter number of booking changes: "))
waiting=int(input("Enter number of days in waiting list: "))
adr=float(input("Enter Average Daily Rate : "))
parking=int(input("Enter number of required car parking spaces: "))
requests=int(input("Enter total number of special requests: "))

unknown_x=[[hotel, lead, week, day, repeted, cancellations, not_canceled, changes, waiting, adr, parking, requests]]

model.predict(unknown_x)
# Out:
# Enter 0.0 for city hotel and 1.0 for resort hotel: 1
# Enter lead time: 85
# Enter arrival date week number: 10
# Enter arrival date day of month: 4
# Enter 1 for repeted guest and 0 for not repeated guest: 1
# Enter number of previous cancallations: 1
# Enter number of previous bookings not canceled: 0
# Enter number of booking changes: 0
# Enter number of days in waiting list: 4
# Enter Average Daily Rate : 105.5
# Enter number of required car parking spaces: 1
# Enter total number of special requests: 2
# array([1])

# %%
prediction=model.predict(unknown_x)
if(prediction==0):
    print("Booking was not canceled")
else:
    print("Booking was canceled")
# Out:
# Booking was canceled

# %% [markdown]
# **Observation and Suggestions**

# %% [markdown]
# Resort Hotel is most preffered so, Stakeholders can offer discounts on City Hotel to increase bookings.
#
# Around 27.52% of bookings are cancelled so Hotel can offer discounts if guests don't cancel their booking.
#
# Hotel should increase number of rooms in City Hotels to decrease the waiting time.
#
# TA has the most number of bookings over other Market segments so Hotel could run some offer to get more bookings from other segments.
#
# Room type A is most preffered by guests so Hotel should increase the number of A type room.
#
# Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
#
# Maximum number of guests were from Portugal.So, the hotels should increase the advertisement so that equal number of guests come from other countries.
